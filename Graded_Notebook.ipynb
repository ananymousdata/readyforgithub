# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Anand Singh</b><br>
# Data Science Trainee

# %% [markdown]
# <i>I am interested in data science because I want to upskill to learn more knowledge, achieve higher position, and earn more money. </i>

# %% [markdown]
# The code I'm going to write in cell 5 will add two numbers and then print the results

# %%
print(100+278)
# Out:
# 378

# %% [markdown]
# <hr>
# <p>This is what I have learned in this notbook-</p>
# <ul>
#   <li>Changing code cell to markdown</li>
#   <li>How to define headlines</li>
#   <li>How to use HTML in markdown to make it more appealing and clean</li>
# </ul>
# <hr>
# <blockquote>Here is my GitHub Profile: <a href="https://github.com/ananymousdata">Click Here</a></blockquote>
#  <b>Thank You Guys</b> for Your Reviews
